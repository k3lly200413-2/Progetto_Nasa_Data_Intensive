# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

# %%
import opendatasets

# %%
import kaggle

# %%
URL = "https://www.kaggle.com/datasets/darkmatternet/nasa-near-earth-asteroids-and-close-approaches"

# %%
data_dir = opendatasets.download(URL)
# Out:
# Skipping, found downloaded files in ".\nasa-near-earth-asteroids-and-close-approaches" (use force=True to force download)

# %% [markdown]
# ### Kaggle's dataset description:
#
# The complete catalog of every known Near-Earth Asteroid (NEA) from NASA's Jet Propulsion Laboratory, plus 20 years of close approach data (2015-2035).

# %% [markdown]
# ### Definition of Potentially Hazardous Asteroids
#
# Nasa defines the Potentially Hazardous Asteroids (PHAs) based on parameters that measure the asteroid’s potential to make threatening close approaches to the Earth. Specifically, all asteroids with a minimum orbit intersection distance (MOID) of 0.05 au or less and an absolute magnitude (H) of 22.0 or less, the latter of which roughly corresponds to a size larger than 140 meters, are considered PHAs.

# %%
close_approaches = pd.read_csv("./nasa-near-earth-asteroids-and-close-approaches/asteroid_close_approaches_2015_2035 (1).csv")

# %%
near_earth = pd.read_csv("./nasa-near-earth-asteroids-and-close-approaches/near_earth_asteroids_2025 (1).csv", dtype = {3: str})

# %% [markdown]
# ### Descrizione delle colonne di close_approaches
#
# | Column | Description |
# | ------ | ----------- |
# | designation |	Asteroid designation |
# | full_name	|Full asteroid name	|
# | close_approach_date | Date and time of closest approach (UTC)
# | distance_au	| Miss distance in Astronomical Units
# | dist_km	| Miss distance in kilometers
# | dist_lunar	| Miss distance in lunar distances
# | distance_min_au	| Minimum possible distance (3-sigma) in AU
# | distance_max_au	| Maximum possible distance (3-sigma) in AU
# | velocity_km_s	| Relative velocity at close approach in km/s
# | v_rel_kmh	| Relative velocity in km/h
# | velocity_infinity_km_s	| Velocity at infinity in km/s
# | absolute_magnitude	| Absolute magnitude H of the asteroid
# | is_future	| Whether the approach is in the future

# %% [markdown]
# Ulteriore spiegazione delle variabili:

# %% [markdown]
# ##### designation:
# The designation can be temporary (year of discovery, one letter indicating the half-month of the object's discovery within that year and ranges from A (first half of January) to Y (second half of December) and another letter with a numerical suffix indicating the order of discovery within that half-month. The first 25 discoveries of the half-month receive a letter A to Z (excluding the letter I, which is not used to avoid confusion with the digit 1). Because modern techniques typically yield hundreds if not thousands of discoveries per half-month, a subscript number is appended to subsequent discoveries within that half-month to indicate the number of times that the letters A to Z have been cycled through. Thus the suffix 1 indicates discoveries after one completed cycle, namely the 26th through 50th discoveries.
#
# The permanent designation is a unique numerical sequence.
# <pre>
# Example:
#   provisonal designation -> 2005 YQ96
#   permanent  designation -> 613286
# </pre>

# %% [markdown]
# ##### full_name:
# The combination of the permanent and provisonal designations
# <pre>
# Example:
#   613286 (2005 YQ96)
# </pre>

# %% [markdown]
# ##### close_approach_date:
# The date and time of closest approach in a date format
# <pre>
# Example: 2015-01-02 21:46
# </pre>

# %% [markdown]
# ##### distance_au, dist_km and dist_lunar:
# The miss distance in Astronomical Units (AU) and Kilometers (km), AU is a unit of length defined as exactly equal to 149597870700 m or approximately <br>150 million km, a lunar distance is the distance between Earth and the Moon: 384399 km.
# <pre>
# example:
#     distance_au ->       0.026522
#     dist_km     -> 3967664.0
#     dist_lunar  ->      10.32
# </pre>

# %% [markdown]
# ##### distance_min_au and distance_max_au
# The minimum and maximum possible distance is based on the 3-sigma Earth target-plane error ellipse. <br>
# The minimum distance is the closest possible the asteroid could get, given the current errors in our data. <br>
# The maximum distance is the farthest possible the asteroid could be during that specific approach. <br>
# <pre>
# Example:
#     asteroid 613286 has distance_au = distance_min_au = distance_max_au.
#     That is because we have been able to calculate with a neglectable error its orbit
# </pre>

# %% [markdown]
# ##### velocity_infinity_km_s
#
# For asteroids it refers to an object’s speed relative to a planet (Earth in this case) or the Sun when it is far enough away to be unaffected by its gravity. <br>
# Normally $v_{\infty}$ is lower than $v_{rel}$ because the asteroids doesn't get pulled by earth's gravity

# %% [markdown]
# ##### absolute_magnitude
# absolute magnitude (M) is a measure of the luminosity of a celestial object, the more luminous (intrinsically bright) an object, the lower its magnitude number.
# An asteroid’s absolute magnitude is the visual magnitude an observer would record if the asteroid were placed 1 Astronomical Unit (au) away, and 1 au from the Sun and at a zero phase angle.

# %% [markdown]
# ##### is_future
# boolean: <br>
# True if the close_approach_date is in the future, False otherwise

# %%
close_approaches.loc[close_approaches["is_future"] == True].sort_values("close_approach_date")
# Out:
#       designation           full_name close_approach_date  distance_au  \
# 23542    2026 FG4          (2026 FG4)    2026-03-25 13:51     0.011928
# 23543   2025 SP20         (2025 SP20)    2026-03-25 16:08     0.048047
# 23544    2026 FB3          (2026 FB3)    2026-03-26 12:01     0.018854
# 23545    2026 FB4          (2026 FB4)    2026-03-26 20:48     0.004343
# 23546    2026 FA3          (2026 FA3)    2026-03-27 05:09     0.019181
# ...           ...                 ...                 ...          ...
# 27425    2025 AC1          (2025 AC1)    2035-12-26 08:22     0.083559
# 27426    2024 YF1          (2024 YF1)    2035-12-27 13:18     0.089199
# 27427    2025 PN7          (2025 PN7)    2035-12-27 21:30     0.058551
# 27428    2022 YS6          (2022 YS6)    2035-12-28 08:54     0.024968
# 27429   2024 WX15         (2024 WX15)    2035-12-29 10:15     0.060425
#
#           dist_km  dist_lunar  distance_min_au  distance_max_au  \
# 23542   1784467.0        4.64         0.011899         0.011958
# 23543   7187775.0       18.70         0.046941         0.049154
# 23544   2820484.0        7.34         0.018751         0.018956
# 23545    649770.0        1.69         0.004335         0.004352
# 23546   2869442.0        7.46         0.019065         0.019297
# ...           ...         ...              ...              ...
# 27425  12500228.0       32.52         0.066438         0.100799
# 27426  13343971.0       34.71         0.088964         0.141531
# 27427   8759067.0       22.79         0.058549         0.058552
# 27428   3735173.0        9.72         0.004201         0.046292
# 27429   9039430.0       23.52         0.059768         0.062458
#
#        velocity_km_s  v_rel_kmh  velocity_infinity_km_s  absolute_magnitude  \
# 23542      10.867494    39123.0               10.846920              28.540
# 23543      10.957208    39446.0               10.952146              27.370
# 23544      13.097016    47149.0               13.086221              26.513
# 23545      10.428562    37543.0               10.369572              27.911
# 23546      13.771230    49576.0               13.761139              26.722
# ...              ...        ...                     ...                 ...
# 27425       8.709480    31354.0                8.705818              26.890
# 27426      10.708675    38551.0               10.705885              23.540
# 27427       1.831257     6593.0                1.806236              26.410
# 27428       9.403958    33854.0                9.392603              26.860
# 27429       5.940014    21384.0                5.932586              24.270
#
#        is_future
# 23542       True
# 23543       True
# 23544       True
# 23545       True
# 23546       True
# ...          ...
# 27425       True
# 27426       True
# 27427       True
# 27428       True
# 27429       True
#
# [3888 rows x 13 columns]

# %%
close_approaches.iloc[2]
# Out:
# designation                           613286
# full_name                 613286 (2005 YQ96)
# close_approach_date         2015-01-02 21:46
# distance_au                         0.026522
# dist_km                            3967664.0
# dist_lunar                             10.32
# distance_min_au                     0.026522
# distance_max_au                     0.026522
# velocity_km_s                      12.703378
# v_rel_kmh                            45732.0
# velocity_infinity_km_s             12.695467
# absolute_magnitude                     20.63
# is_future                              False
# Name: 2, dtype: object

# %% [markdown]
# | column | description |
# | ------ | ----------- |
# |full_name | Full asteroid name/designation |
# |designation|	Primary designation (e.g. '2024 AA')	|
# |spkid|	JPL Small-Body SPK-ID (unique identifier)	|
# |is_pha	|Potentially Hazardous Asteroid flag	|
# |neo_class|	Orbit class: Apollo, Aten, Amor, or Atira |
# |absolute_magnitude	|Absolute magnitude H (brightness, proxy for size) |
# |diameter_km|	Estimated diameter in kilometers	|
# |diameter_min_km	|Minimum estimated diameter in km|
# |diameter_max_km|	Maximum estimated diameter in km|
# |size_category|	City Killer, Regional Damage, Local Damage, Small, Tiny	|
# |albedo|	Surface reflectivity (0 to 1)	|
# |rotation_period_h	|Rotation period in hours |
# |spectral_type|	Spectral classification (S, C, X, etc.)	|
# |eccentricity|	Orbital eccentricity (0=circular, 1=parabolic)	|
# |semi_major_axis_au|	Semi-major axis in AU	|
# |inclination_deg|	Orbital inclination in degrees	|
# |perihelion_au|	Closest distance to the Sun in AU	|
# |aphelion_au	|Farthest distance from the Sun in AU	|
# |orbital_period_yr	|Orbital period in years	|
# |moid_au	|Minimum Orbit Intersection Distance in AU	|
# |moid_km|	MOID in kilometers	|
# |moid_lunar	|MOID in lunar distances (1 LD ≈ 384,400 km)	|
# |n_observations	|Number of astrometric observations	|
# |data_arc_days|	Observation arc length in days	|
# |orbit_condition_code|	Orbit quality (0=best, 9=worst)	|
# |first_observed|Date of first observation	|
# |last_observed|	Date of most recent observation |

# %% [markdown]
# Ulteriore descrizione delle variabili

# %%
near_earth.columns
# Out:
# Index(['spkid', 'full_name', 'pdes', 'name', 'pha', 'H', 'diameter_km',
#        'diameter_m', 'diameter_is_estimated', 'size_category', 'albedo',
#        'rot_per', 'class', 'e', 'a', 'i', 'q', 'ad', 'per', 'per_y', 'moid_au',
#        'moid_km', 'moid_lunar_distances', 'n', 'condition_code', 'first_obs',
#        'last_obs', 'data_arc', 'data_arc_years'],
#       dtype='object')

# %%
near_earth.head()
# Out:
#       spkid                 full_name  pdes     name    pha      H  \
# 0  20000433        433 Eros (A898 PA)   433     Eros  False  10.39
# 1  20000719      719 Albert (A911 TB)   719   Albert  False  15.59
# 2  20000887      887 Alinda (A918 AA)   887   Alinda  False  13.82
# 3  20001036    1036 Ganymed (A924 UB)  1036  Ganymed  False   9.17
# 4  20001221      1221 Amor (1932 EA1)  1221     Amor  False  17.37
#
#    diameter_km  diameter_m  diameter_is_estimated  \
# 0     16.84000     16840.0                  False
# 1      2.70683      2706.8                   True
# 2      4.20000      4200.0                  False
# 3     37.67500     37675.0                  False
# 4      1.00000      1000.0                  False
#
#                   size_category  albedo  rot_per class       e      a      i  \
# 0  Large (>1 km) — City killer+   0.250    5.270   AMO  0.2228  1.458  10.83
# 1  Large (>1 km) — City killer+     NaN    5.801   AMO  0.5466  2.637  11.57
# 2  Large (>1 km) — City killer+   0.310   28.410   AMO  0.5712  2.474   9.40
# 3  Large (>1 km) — City killer+   0.238   10.297   AMO  0.5332  2.665  26.68
# 4  Large (>1 km) — City killer+     NaN      NaN   AMO  0.4346  1.920  11.87
#
#        q    ad     per  per_y  moid_au     moid_km  moid_lunar_distances  \
# 0  1.133  1.78   643.0   1.76   0.1480  22140485.0                 57.60
# 1  1.195  4.08  1560.0   4.28   0.2010  30069172.0                 78.22
# 2  1.061  3.89  1420.0   3.89   0.0797  11922950.0                 31.02
# 3  1.244  4.09  1590.0   4.35   0.3430  51312070.0                133.49
# 4  1.085  2.75   972.0   2.66   0.1080  16156570.0                 42.03
#
#         n  condition_code   first_obs    last_obs  data_arc  data_arc_years
# 0  0.5598             0.0  1893-10-29  2021-05-13   46582.0          127.53
# 1  0.2302             0.0  1911-10-04  2026-03-20   41806.0          114.46
# 2  0.2533             0.0  1918-02-09  2025-08-27   39281.0          107.55
# 3  0.2266             0.0  1924-10-23  2026-03-22   37040.0          101.41
# 4  0.3705             0.0  1932-03-12  2025-02-19   33947.0           92.94

# %%
near_earth.tail()
# Out:
#           spkid          full_name      pdes name    pha      H  diameter_km  \
# 41276  54606826         (2026 FJ4)  2026 FJ4  NaN  False  20.85     0.240138
# 41277  54606825         (2026 FK4)  2026 FK4  NaN  False  27.55     0.010976
# 41278  54606827         (2026 FL4)  2026 FL4  NaN  False  27.07     0.013692
# 41279  54606828         (2026 FM4)  2026 FM4  NaN  False  25.77     0.024915
# 41280   3013075         (6344 P-L)  6344 P-L  NaN   True  20.52     0.279551
#
#        diameter_m  diameter_is_estimated                        size_category  \
# 41276       240.1                   True  Medium (140m-1km) — Regional damage
# 41277        11.0                   True      Tiny (<25m) — Airburst/harmless
# 41278        13.7                   True      Tiny (<25m) — Airburst/harmless
# 41279        24.9                   True      Tiny (<25m) — Airburst/harmless
# 41280       279.6                   True  Medium (140m-1km) — Regional damage
#
#        albedo  rot_per class       e      a      i      q    ad     per  \
# 41276     NaN      NaN   AMO  0.5067  2.317  28.16  1.143  3.49  1290.0
# 41277     NaN      NaN   APO  0.5668  2.117   1.53  0.917  3.32  1130.0
# 41278     NaN      NaN   APO  0.7362  2.687   1.66  0.709  4.66  1610.0
# 41279     NaN      NaN   APO  0.5170  2.023   3.20  0.977  3.07  1050.0
# 41280     NaN      NaN   APO  0.6617  2.821   4.68  0.954  4.69  1730.0
#
#        per_y   moid_au     moid_km  moid_lunar_distances       n  \
# 41276   3.53  0.191000  28573193.0                 74.33  0.2795
# 41277   3.08  0.000852    127457.0                  0.33  0.3199
# 41278   4.40  0.008870   1326933.0                  3.45  0.2238
# 41279   2.88  0.039400   5894156.0                 15.33  0.3427
# 41280   4.74  0.036700   5490242.0                 14.28  0.2081
#
#        condition_code   first_obs    last_obs  data_arc  data_arc_years
# 41276             9.0  2026-03-22  2026-03-24       2.0            0.01
# 41277             9.0  2026-03-21  2026-03-24       3.0            0.01
# 41278             9.0  2026-03-21  2026-03-23       2.0            0.01
# 41279             8.0  2026-03-23  2026-03-25       2.0            0.01
# 41280             0.0  1960-09-24  2021-08-04   22229.0           60.86

# %% [markdown]
# Ulteriore spiegazione delle variabili:

# %% [markdown]
# vuol dire che il lavoro successivo di merge sugli spkid si può riformulare

# %% [markdown]
# ##### JPL Small-Body SPK-ID
# The JPL Small-Body SPK-ID is a unique integer assigned by NASA's Jet Propulsion Laboratory (JPL) to every asteroid, comet, or planet in their database.
# It's a different unique number from the permanent designation.

# %% [markdown]
# ##### full_name
# Full name is the combined primary and provisional designation of a celestial body
# <pre>
# Example:
#     433 Eros (A898 PA) => primary designation = 433, proper name = Eros, provisional key = A898 PA
# </pre>

# %% [markdown]
# ##### pdes
# Primary Designation is the main identifier used for a body; this can be either the permanent number if the body has been officially numbered, or the provisional designation if it hasn't been numbered yet.
# <pre>
#     spkid       full_name           pdes
#
#     20000433	433 Eros (A898 PA)	433
#
#     54606826	(2026 FJ4)	        2026 FJ
# </pre>

# %% [markdown]
# ##### name
# Proper Name given to bodies which are particularly important, given only if body has been already numbered
#
# <pre>
# Example:
#     spkid       full_name           pdes        name
#
#     20000433	433 Eros (A898 PA)	433	Eros    Eros
#     54606826	(2026 FJ4)	        2026 FJ4    NaN
#
# </pre>

# %% [markdown]
# ##### diameter_km
# Lenght of the diameter of body expressed in kilometers

# %% [markdown]
# ##### diameter_m
# Lenght of the diameter of body expressed in meters

# %% [markdown]
# ##### diameter_is_estimated
# Boolean to show whether the diameter has been estimated or properly measured

# %% [markdown]
# ##### size_category
# Category to show what type of body an asteroid is based on the size:
# <pre>
# Example:
#
#     Large (>1 km) —     City killer+
#     Medium (140m-1km) — Regional damage
#     Tiny (<25m) —       Airburst/harmless
# </pre>

# %% [markdown]
# ##### albedo
# Surface reflectivity of the asteroid, ranging from 0 to 1. Useful because a darker body needs to be bigger to appear brighter

# %% [markdown]
# ##### Rot_per
# Rotation period for each body

# %% [markdown]
# ##### class
# Orbital class of the asteroid
#
# <pre>
# Example:
#
#     AMOrs   - a > 1.0 AU - 1.017 AU < q < 1.3 AU
#     APOllos - a > 1.0 AU - q < 1.017 AU
#     ATEns   - a < 1.0 AU - Q > 0.983 AU
#     ATIras  - a < 1.0 AU - Q < 0.983 AU
#
# </pre>

# %% [markdown]
# ##### e
# Eccentricity ranges from 0 to 1 to indicate how circular or parabolic an orbit is.
#
# <pre>
# Example:
#
#     0 => circular orbit
#     1 => parabolic orbit
# </pre>

# %% [markdown]
# ##### a
# Semi-major axis is the semidiameter that runs through the center and one of the foci of the orbit; in this case average distance of the body from the Sun it orbits

# %% [markdown]
# ##### i
# inclination degrees, tilt of the asteroid's orbit relative to the plane of the Solar System; 0° perfectly flat orbit aligned with earth's

# %% [markdown]
# ##### q
# Perihelion is the closest point of the asteroid's orbit to the Sun in AU

# %% [markdown]
# ##### ad
# Aphelion farthest point from the sun in AU

# %% [markdown]
# ##### per
# Time asteroid takes to complete one full orbit around the Sun

# %% [markdown]
# ##### per_y
# Time asteroid takes to complete one full orbit around the Sun in years

# %% [markdown]
# ##### moid_au
#
# Minimum orbit intersection distance is the closest possible distance between the asteroid's orbit and Earth's orbit in AU

# %% [markdown]
# ##### moid_km
#
# Minimum orbit intersection distance is the closest possible distance between the asteroid's orbit and Earth's orbit in km

# %% [markdown]
# ##### moid_lunar_distance
#
# Minimum orbit intersection distance is the closest possible distance between the asteroid's orbit and Earth's orbit in lunar distance

# %% [markdown]
# ##### n
# number of observations of a specific body

# %% [markdown]
# ##### condition_code
#
# quality score of how well the asteroid's orbit is known (0 - 9)

# %% [markdown]
# ##### first_obs
#
# Date of the first observation of the body

# %% [markdown]
# ##### last_obs
#
# Date of the last observation of the body

# %% [markdown]
# ##### data_arc
#
# length of time between first and last observation

# %% [markdown]
# ### Checking how many null values are in each dataframe

# %% [markdown]
# ### Analizing missing data from columns

# %% [markdown]
# **Velocity_infinity_km_s** could have null elements due to different factors, the most likely reason as to the absense of these data points is that there simply wasn't enough data to compute, seeing as velocity_km_s has no nulls these missing data points shuoldn't cause too many issues

# %% [markdown]
# **absolute_magnitude** likely has null data points due to a lack of data from the original database

# %% [markdown]
# **skpid** can contain missing data points due to the asteroid being recently discovered and not yet in the `near_earth` dataset, a merge logic error, or un update to the database between the two dataset versions

# %% [markdown]
# **name** may be missing due to the body not being of importance

# %% [markdown]
# **H** [See absolute magnitude in "close_approaches"]

# %% [markdown]
# **albedo** is a complex measurement, potentially reserved for more significant bodies

# %% [markdown]
# **rot_per** similar to _albedo_ is not a simple mesurement so potentially reserved for more significant bodies

# %% [markdown]
# **moid_au/km/lunar_distance** could be due to missing mesurements or a high condition score, this is important because moid is a defining factor when determining PHA classification

# %% [markdown]
# **condition_code** could be due to a body being discovered before the implementation of condition codes, data entry errors or other edge cases

# %% [markdown]
# **data_arc/years** seeing as only one observation date is missing these missing data points are given by the fact that the first and last observation where the same date

# %% [markdown]
# **key_num** asteroid has not yet been numbered, it only holds a provisional name

# %%
near_earth.columns
# Out:
# Index(['spkid', 'full_name', 'pdes', 'name', 'pha', 'H', 'diameter_km',
#        'diameter_m', 'diameter_is_estimated', 'size_category', 'albedo',
#        'rot_per', 'class', 'e', 'a', 'i', 'q', 'ad', 'per', 'per_y', 'moid_au',
#        'moid_km', 'moid_lunar_distances', 'n', 'condition_code', 'first_obs',
#        'last_obs', 'data_arc', 'data_arc_years'],
#       dtype='object')

# %%
close_approaches.columns
# Out:
# Index(['designation', 'full_name', 'close_approach_date', 'distance_au',
#        'dist_km', 'dist_lunar', 'distance_min_au', 'distance_max_au',
#        'velocity_km_s', 'v_rel_kmh', 'velocity_infinity_km_s',
#        'absolute_magnitude', 'is_future'],
#       dtype='object')

# %% [markdown]
# near_earth e close_approaches condividono la colonna "full_name", verifichiamo che condividano la rappresentazione per poter effettuare il merge.

# %%
close_approaches.full_name
# Out:
# 0                (2022 AP1)
# 1               (2015 AE45)
# 2        613286 (2005 YQ96)
# 3               (2014 YQ34)
# 4               (2014 YE42)
#                 ...
# 27425            (2025 AC1)
# 27426            (2024 YF1)
# 27427            (2025 PN7)
# 27428            (2022 YS6)
# 27429           (2024 WX15)
# Name: full_name, Length: 27430, dtype: object

# %%
near_earth.full_name
# Out:
# 0              433 Eros (A898 PA)
# 1            719 Albert (A911 TB)
# 2            887 Alinda (A918 AA)
# 3          1036 Ganymed (A924 UB)
# 4            1221 Amor (1932 EA1)
#                    ...
# 41276                  (2026 FJ4)
# 41277                  (2026 FK4)
# 41278                  (2026 FL4)
# 41279                  (2026 FM4)
# 41280                  (6344 P-L)
# Name: full_name, Length: 41281, dtype: object

# %% [markdown]
# notiamo che la rappresentazione è la medesima.

# %% [markdown]
# close_approaches raccoglie i dati di tutti i close_approaches per l'appunto, quindi si hanno molteplici asteroidi uguali che sono passati più volte vicino alla Terra.

# %%
print(close_approaches['full_name'].duplicated().sum())
# Out:
# 6544

# %% [markdown]
# near_earth invece raccoglie dati su l'asteroide in sé, non deve quindi avere istanze ripetute, ciò è importante anche perché il merge vada a buon fine (per evitare la moltiplicazione di valori).

# %%
print(near_earth["full_name"].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Per sicurezza uniformiamo i valori presenti in "full name" sia in close_approaches che in near_earth.

# %%
close_approaches['full_name'] = close_approaches['full_name'].astype(str).str.strip()
near_earth['full_name'] = near_earth['full_name'].astype(str).str.strip()

# %% [markdown]
# Effettuiamo il merge dei dati di near_earth su close_approaches.

# %%
merged = pd.merge(close_approaches, near_earth, on="full_name", how='left')

# %%
close_approaches.shape
# Out:
# (27430, 13)

# %%
merged.shape
# Out:
# (27430, 41)

# %%
merged
# Out:
#       designation           full_name close_approach_date  distance_au  \
# 0        2022 AP1          (2022 AP1)    2015-01-01 00:27     0.045100
# 1       2015 AE45         (2015 AE45)    2015-01-02 15:56     0.048239
# 2          613286  613286 (2005 YQ96)    2015-01-02 21:46     0.026522
# 3       2014 YQ34         (2014 YQ34)    2015-01-03 13:29     0.079692
# 4       2014 YE42         (2014 YE42)    2015-01-03 15:00     0.010995
# ...           ...                 ...                 ...          ...
# 27425    2025 AC1          (2025 AC1)    2035-12-26 08:22     0.083559
# 27426    2024 YF1          (2024 YF1)    2035-12-27 13:18     0.089199
# 27427    2025 PN7          (2025 PN7)    2035-12-27 21:30     0.058551
# 27428    2022 YS6          (2022 YS6)    2035-12-28 08:54     0.024968
# 27429   2024 WX15         (2024 WX15)    2035-12-29 10:15     0.060425
#
#           dist_km  dist_lunar  distance_min_au  distance_max_au  \
# 0       6746806.0       17.55         0.013778         0.076571
# 1       7216474.0       18.77         0.048220         0.048258
# 2       3967664.0       10.32         0.026522         0.026522
# 3      11921722.0       31.01         0.078275         0.081108
# 4       1644896.0        4.28         0.010971         0.011020
# ...           ...         ...              ...              ...
# 27425  12500228.0       32.52         0.066438         0.100799
# 27426  13343971.0       34.71         0.088964         0.141531
# 27427   8759067.0       22.79         0.058549         0.058552
# 27428   3735173.0        9.72         0.004201         0.046292
# 27429   9039430.0       23.52         0.059768         0.062458
#
#        velocity_km_s  v_rel_kmh  velocity_infinity_km_s  absolute_magnitude  \
# 0          11.891749    42810.0               11.886780               28.39
# 1           7.065686    25436.0                7.057864               25.30
# 2          12.703378    45732.0               12.695467               20.63
# 3          24.982094    89936.0               24.980756               24.16
# 4          13.998882    50396.0               13.981561               23.40
# ...              ...        ...                     ...                 ...
# 27425       8.709480    31354.0                8.705818               26.89
# 27426      10.708675    38551.0               10.705885               23.54
# 27427       1.831257     6593.0                1.806236               26.41
# 27428       9.403958    33854.0                9.392603               26.86
# 27429       5.940014    21384.0                5.932586               24.27
#
#        is_future       spkid       pdes name    pha      H  diameter_km  \
# 0          False  54235525.0   2022 AP1  NaN  False  28.39     0.007455
# 1          False   3703782.0  2015 AE45  NaN  False  25.30     0.030936
# 2          False  20613286.0     613286  NaN   True  20.63     0.265742
# 3          False   3703076.0  2014 YQ34  NaN  False  24.16     0.052295
# 4          False   3703248.0  2014 YE42  NaN  False  23.40     0.074210
# ...          ...         ...        ...  ...    ...    ...          ...
# 27425       True  54514244.0   2025 AC1  NaN  False  26.89     0.014875
# 27426       True  54507933.0   2024 YF1  NaN  False  23.54     0.069576
# 27427       True  54542757.0   2025 PN7  NaN  False  26.41     0.018555
# 27428       True  54337425.0   2022 YS6  NaN  False  26.86     0.015082
# 27429       True  54502459.0  2024 WX15  NaN  False  24.27     0.049712
#
#        diameter_m diameter_is_estimated                        size_category  \
# 0             7.5                  True      Tiny (<25m) — Airburst/harmless
# 1            30.9                  True       Small (25-140m) — Local damage
# 2           265.7                  True  Medium (140m-1km) — Regional damage
# 3            52.3                  True       Small (25-140m) — Local damage
# 4            74.2                  True       Small (25-140m) — Local damage
# ...           ...                   ...                                  ...
# 27425        14.9                  True      Tiny (<25m) — Airburst/harmless
# 27426        69.6                  True       Small (25-140m) — Local damage
# 27427        18.6                  True      Tiny (<25m) — Airburst/harmless
# 27428        15.1                  True      Tiny (<25m) — Airburst/harmless
# 27429        49.7                  True       Small (25-140m) — Local damage
#
#        albedo  rot_per class       e       a      i      q    ad     per  \
# 0         NaN      NaN   ATE  0.4483  0.7331   2.90  0.404  1.06   229.0
# 1         NaN      NaN   APO  0.3027  1.3670   9.50  0.953  1.78   584.0
# 2         NaN      NaN   ATE  0.3336  0.7434  22.23  0.495  0.99   234.0
# 3         NaN      NaN   APO  0.8311  2.5240   3.43  0.426  4.62  1460.0
# 4         NaN      NaN   APO  0.6253  2.2720   6.61  0.851  3.69  1250.0
# ...       ...      ...   ...     ...     ...    ...    ...   ...     ...
# 27425     NaN      NaN   ATE  0.2225  0.8524   6.40  0.663  1.04   287.0
# 27426     NaN      NaN   APO  0.1464  1.0640  18.89  0.908  1.22   401.0
# 27427     NaN      NaN   APO  0.1079  1.0010   1.98  0.893  1.11   366.0
# 27428     NaN      NaN   ATE  0.4874  0.6838   2.64  0.351  1.02   207.0
# 27429     NaN      NaN   ATE  0.2771  0.8129   4.45  0.588  1.04   268.0
#
#        per_y   moid_au    moid_km  moid_lunar_distances       n  \
# 0      0.628  0.000898   134339.0                  0.35  1.5700
# 1      1.600  0.032400  4846971.0                 12.61  0.6167
# 2      0.641  0.019200  2872279.0                  7.47  1.5380
# 3      4.010  0.006380   954434.0                  2.48  0.2458
# 4      3.420  0.001430   213925.0                  0.56  0.2879
# ...      ...       ...        ...                   ...     ...
# 27425  0.787  0.002690   402418.0                  1.05  1.2520
# 27426  1.100  0.012700  1899893.0                  4.94  0.8979
# 27427  1.000  0.002820   421866.0                  1.10  0.9841
# 27428  0.565  0.001330   198965.0                  0.52  1.7430
# 27429  0.733  0.010300  1540858.0                  4.01  1.3450
#
#        condition_code   first_obs    last_obs  data_arc  data_arc_years
# 0                 7.0  2022-01-04  2022-01-09       5.0            0.01
# 1                 6.0  2015-01-15  2015-02-19      35.0            0.10
# 2                 0.0  2005-12-30  2023-12-15    6559.0           17.96
# 3                 9.0  2014-12-23  2014-12-29       6.0            0.02
# 4                 7.0  2014-12-30  2015-01-04       5.0            0.01
# ...               ...         ...         ...       ...             ...
# 27425             6.0  2025-01-03  2025-01-22      19.0            0.05
# 27426             7.0  2024-12-21  2025-01-03      13.0            0.04
# 27427             0.0  2013-12-11  2025-08-29    4279.0           11.72
# 27428             7.0  2022-12-24  2023-01-02       9.0            0.02
# 27429             6.0  2024-11-29  2025-01-07      39.0            0.11
#
# [27430 rows x 41 columns]

# %% [markdown]
# Verifichiamo la presenza di NaN:

# %%
merged.isnull().sum()[merged.isnull().sum() > 0]
# Out:
# velocity_infinity_km_s       17
# absolute_magnitude            8
# spkid                         8
# pdes                          8
# name                      27389
# pha                           8
# H                             8
# diameter_km                   8
# diameter_m                    8
# diameter_is_estimated         8
# size_category                 8
# albedo                    27068
# rot_per                   26131
# class                         8
# e                             8
# a                             8
# i                             8
# q                             8
# ad                            8
# per                           8
# per_y                         8
# moid_au                       8
# moid_km                       8
# moid_lunar_distances          8
# n                             8
# condition_code                8
# first_obs                     8
# last_obs                      8
# data_arc                    360
# data_arc_years              360
# dtype: int64

# %% [markdown]
# Si nota subito che alcune variabili sono molto assenti: <br>
# name; albedo; rot_per; <br>
# e altre che non ci interessano: <br>
# first_obs; last_obs; data_arc; data_arc_years
# iniziamo con il provare a rimuoverle. <br>

# %%
merged = merged.drop(['name', 'rot_per', 'first_obs', 'last_obs', 'data_arc', 'data_arc_years', 'albedo'], axis=1)

# %%
merged.shape
# Out:
# (27430, 34)

# %%
merged.isnull().sum()[merged.isnull().sum() > 0]
# Out:
# velocity_infinity_km_s    17
# absolute_magnitude         8
# spkid                      8
# pdes                       8
# pha                        8
# H                          8
# diameter_km                8
# diameter_m                 8
# diameter_is_estimated      8
# size_category              8
# class                      8
# e                          8
# a                          8
# i                          8
# q                          8
# ad                         8
# per                        8
# per_y                      8
# moid_au                    8
# moid_km                    8
# moid_lunar_distances       8
# n                          8
# condition_code             8
# dtype: int64

# %% [markdown]
# La seconda cosa che si nota è la presenza di 8 valori NaN in ogni colonna; ciò probabilmente è causato dall'assenza in near_earth di alcuni asteroidi presenti invece in close_approaches.

# %%
merged[merged['spkid'].isna()]['full_name'].unique()
# Out:
# array(['252P/LINEAR', '460P/PANSTARRS', '45P/Honda-Mrkos-Pajdusakova',
#        '46P/Wirtanen', '289P/Blanpain', '249P/LINEAR'], dtype=object)

# %%
merged[merged['spkid'].isna()]['full_name'].value_counts()
# Out:
# full_name
# 252P/LINEAR                    2
# 289P/Blanpain                  2
# 460P/PANSTARRS                 1
# 45P/Honda-Mrkos-Pajdusakova    1
# 46P/Wirtanen                   1
# 249P/LINEAR                    1
# Name: count, dtype: int64

# %% [markdown]
# Ci sono quindi 6 asteroidi mancanti in near_earth che compaiono 8 volte in close_approaches. Il loro numero è esiguo quindi si possono pulire semplicemente senza curarcene troppo.

# %%
merged = merged.dropna()

# %%
merged.isnull().sum()[merged.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# merged ora è completamente pulito dai NaN

# %%
pd.set_option('display.max_columns', None)
merged
# Out:
#       designation           full_name close_approach_date  distance_au  \
# 0        2022 AP1          (2022 AP1)    2015-01-01 00:27     0.045100
# 1       2015 AE45         (2015 AE45)    2015-01-02 15:56     0.048239
# 2          613286  613286 (2005 YQ96)    2015-01-02 21:46     0.026522
# 3       2014 YQ34         (2014 YQ34)    2015-01-03 13:29     0.079692
# 4       2014 YE42         (2014 YE42)    2015-01-03 15:00     0.010995
# ...           ...                 ...                 ...          ...
# 27425    2025 AC1          (2025 AC1)    2035-12-26 08:22     0.083559
# 27426    2024 YF1          (2024 YF1)    2035-12-27 13:18     0.089199
# 27427    2025 PN7          (2025 PN7)    2035-12-27 21:30     0.058551
# 27428    2022 YS6          (2022 YS6)    2035-12-28 08:54     0.024968
# 27429   2024 WX15         (2024 WX15)    2035-12-29 10:15     0.060425
#
#           dist_km  dist_lunar  distance_min_au  distance_max_au  \
# 0       6746806.0       17.55         0.013778         0.076571
# 1       7216474.0       18.77         0.048220         0.048258
# 2       3967664.0       10.32         0.026522         0.026522
# 3      11921722.0       31.01         0.078275         0.081108
# 4       1644896.0        4.28         0.010971         0.011020
# ...           ...         ...              ...              ...
# 27425  12500228.0       32.52         0.066438         0.100799
# 27426  13343971.0       34.71         0.088964         0.141531
# 27427   8759067.0       22.79         0.058549         0.058552
# 27428   3735173.0        9.72         0.004201         0.046292
# 27429   9039430.0       23.52         0.059768         0.062458
#
#        velocity_km_s  v_rel_kmh  velocity_infinity_km_s  absolute_magnitude  \
# 0          11.891749    42810.0               11.886780               28.39
# 1           7.065686    25436.0                7.057864               25.30
# 2          12.703378    45732.0               12.695467               20.63
# 3          24.982094    89936.0               24.980756               24.16
# 4          13.998882    50396.0               13.981561               23.40
# ...              ...        ...                     ...                 ...
# 27425       8.709480    31354.0                8.705818               26.89
# 27426      10.708675    38551.0               10.705885               23.54
# 27427       1.831257     6593.0                1.806236               26.41
# 27428       9.403958    33854.0                9.392603               26.86
# 27429       5.940014    21384.0                5.932586               24.27
#
#        is_future       spkid       pdes    pha      H  diameter_km  \
# 0          False  54235525.0   2022 AP1  False  28.39     0.007455
# 1          False   3703782.0  2015 AE45  False  25.30     0.030936
# 2          False  20613286.0     613286   True  20.63     0.265742
# 3          False   3703076.0  2014 YQ34  False  24.16     0.052295
# 4          False   3703248.0  2014 YE42  False  23.40     0.074210
# ...          ...         ...        ...    ...    ...          ...
# 27425       True  54514244.0   2025 AC1  False  26.89     0.014875
# 27426       True  54507933.0   2024 YF1  False  23.54     0.069576
# 27427       True  54542757.0   2025 PN7  False  26.41     0.018555
# 27428       True  54337425.0   2022 YS6  False  26.86     0.015082
# 27429       True  54502459.0  2024 WX15  False  24.27     0.049712
#
#        diameter_m diameter_is_estimated                        size_category  \
# 0             7.5                  True      Tiny (<25m) — Airburst/harmless
# 1            30.9                  True       Small (25-140m) — Local damage
# 2           265.7                  True  Medium (140m-1km) — Regional damage
# 3            52.3                  True       Small (25-140m) — Local damage
# 4            74.2                  True       Small (25-140m) — Local damage
# ...           ...                   ...                                  ...
# 27425        14.9                  True      Tiny (<25m) — Airburst/harmless
# 27426        69.6                  True       Small (25-140m) — Local damage
# 27427        18.6                  True      Tiny (<25m) — Airburst/harmless
# 27428        15.1                  True      Tiny (<25m) — Airburst/harmless
# 27429        49.7                  True       Small (25-140m) — Local damage
#
#       class       e       a      i      q    ad     per  per_y   moid_au  \
# 0       ATE  0.4483  0.7331   2.90  0.404  1.06   229.0  0.628  0.000898
# 1       APO  0.3027  1.3670   9.50  0.953  1.78   584.0  1.600  0.032400
# 2       ATE  0.3336  0.7434  22.23  0.495  0.99   234.0  0.641  0.019200
# 3       APO  0.8311  2.5240   3.43  0.426  4.62  1460.0  4.010  0.006380
# 4       APO  0.6253  2.2720   6.61  0.851  3.69  1250.0  3.420  0.001430
# ...     ...     ...     ...    ...    ...   ...     ...    ...       ...
# 27425   ATE  0.2225  0.8524   6.40  0.663  1.04   287.0  0.787  0.002690
# 27426   APO  0.1464  1.0640  18.89  0.908  1.22   401.0  1.100  0.012700
# 27427   APO  0.1079  1.0010   1.98  0.893  1.11   366.0  1.000  0.002820
# 27428   ATE  0.4874  0.6838   2.64  0.351  1.02   207.0  0.565  0.001330
# 27429   ATE  0.2771  0.8129   4.45  0.588  1.04   268.0  0.733  0.010300
#
#          moid_km  moid_lunar_distances       n  condition_code
# 0       134339.0                  0.35  1.5700             7.0
# 1      4846971.0                 12.61  0.6167             6.0
# 2      2872279.0                  7.47  1.5380             0.0
# 3       954434.0                  2.48  0.2458             9.0
# 4       213925.0                  0.56  0.2879             7.0
# ...          ...                   ...     ...             ...
# 27425   402418.0                  1.05  1.2520             6.0
# 27426  1899893.0                  4.94  0.8979             7.0
# 27427   421866.0                  1.10  0.9841             0.0
# 27428   198965.0                  0.52  1.7430             7.0
# 27429  1540858.0                  4.01  1.3450             6.0
#
# [27405 rows x 34 columns]

# %% [markdown]
# Notiamo che ci sono colonne che possono essere ridondanti: "H" e "absolute magnitude"; "designation", "full_name" e "pdes".

# %%
merged = merged.drop(['H','designation', 'pdes'], axis=1)

# %%
merged.shape
# Out:
# (27405, 31)

# %% [markdown]
# Rinominiamo ora alcune colonne per avere uniformità nella nomenclatura.

# %%
close_approaches.rename(columns={"dist_km" : "distance_km", "dist_lunar" : "distance_lunar", "v_rel_kmh" : "velocity_rel_kmh"}, inplace=True)

# %%
merged
# Out:
#                 full_name close_approach_date  distance_au     dist_km  \
# 0              (2022 AP1)    2015-01-01 00:27     0.045100   6746806.0
# 1             (2015 AE45)    2015-01-02 15:56     0.048239   7216474.0
# 2      613286 (2005 YQ96)    2015-01-02 21:46     0.026522   3967664.0
# 3             (2014 YQ34)    2015-01-03 13:29     0.079692  11921722.0
# 4             (2014 YE42)    2015-01-03 15:00     0.010995   1644896.0
# ...                   ...                 ...          ...         ...
# 27425          (2025 AC1)    2035-12-26 08:22     0.083559  12500228.0
# 27426          (2024 YF1)    2035-12-27 13:18     0.089199  13343971.0
# 27427          (2025 PN7)    2035-12-27 21:30     0.058551   8759067.0
# 27428          (2022 YS6)    2035-12-28 08:54     0.024968   3735173.0
# 27429         (2024 WX15)    2035-12-29 10:15     0.060425   9039430.0
#
#        dist_lunar  distance_min_au  distance_max_au  velocity_km_s  v_rel_kmh  \
# 0           17.55         0.013778         0.076571      11.891749    42810.0
# 1           18.77         0.048220         0.048258       7.065686    25436.0
# 2           10.32         0.026522         0.026522      12.703378    45732.0
# 3           31.01         0.078275         0.081108      24.982094    89936.0
# 4            4.28         0.010971         0.011020      13.998882    50396.0
# ...           ...              ...              ...            ...        ...
# 27425       32.52         0.066438         0.100799       8.709480    31354.0
# 27426       34.71         0.088964         0.141531      10.708675    38551.0
# 27427       22.79         0.058549         0.058552       1.831257     6593.0
# 27428        9.72         0.004201         0.046292       9.403958    33854.0
# 27429       23.52         0.059768         0.062458       5.940014    21384.0
#
#        velocity_infinity_km_s  absolute_magnitude  is_future       spkid  \
# 0                   11.886780               28.39      False  54235525.0
# 1                    7.057864               25.30      False   3703782.0
# 2                   12.695467               20.63      False  20613286.0
# 3                   24.980756               24.16      False   3703076.0
# 4                   13.981561               23.40      False   3703248.0
# ...                       ...                 ...        ...         ...
# 27425                8.705818               26.89       True  54514244.0
# 27426               10.705885               23.54       True  54507933.0
# 27427                1.806236               26.41       True  54542757.0
# 27428                9.392603               26.86       True  54337425.0
# 27429                5.932586               24.27       True  54502459.0
#
#          pha  diameter_km  diameter_m diameter_is_estimated  \
# 0      False     0.007455         7.5                  True
# 1      False     0.030936        30.9                  True
# 2       True     0.265742       265.7                  True
# 3      False     0.052295        52.3                  True
# 4      False     0.074210        74.2                  True
# ...      ...          ...         ...                   ...
# 27425  False     0.014875        14.9                  True
# 27426  False     0.069576        69.6                  True
# 27427  False     0.018555        18.6                  True
# 27428  False     0.015082        15.1                  True
# 27429  False     0.049712        49.7                  True
#
#                              size_category class       e       a      i  \
# 0          Tiny (<25m) — Airburst/harmless   ATE  0.4483  0.7331   2.90
# 1           Small (25-140m) — Local damage   APO  0.3027  1.3670   9.50
# 2      Medium (140m-1km) — Regional damage   ATE  0.3336  0.7434  22.23
# 3           Small (25-140m) — Local damage   APO  0.8311  2.5240   3.43
# 4           Small (25-140m) — Local damage   APO  0.6253  2.2720   6.61
# ...                                    ...   ...     ...     ...    ...
# 27425      Tiny (<25m) — Airburst/harmless   ATE  0.2225  0.8524   6.40
# 27426       Small (25-140m) — Local damage   APO  0.1464  1.0640  18.89
# 27427      Tiny (<25m) — Airburst/harmless   APO  0.1079  1.0010   1.98
# 27428      Tiny (<25m) — Airburst/harmless   ATE  0.4874  0.6838   2.64
# 27429       Small (25-140m) — Local damage   ATE  0.2771  0.8129   4.45
#
#            q    ad     per  per_y   moid_au    moid_km  moid_lunar_distances  \
# 0      0.404  1.06   229.0  0.628  0.000898   134339.0                  0.35
# 1      0.953  1.78   584.0  1.600  0.032400  4846971.0                 12.61
# 2      0.495  0.99   234.0  0.641  0.019200  2872279.0                  7.47
# 3      0.426  4.62  1460.0  4.010  0.006380   954434.0                  2.48
# 4      0.851  3.69  1250.0  3.420  0.001430   213925.0                  0.56
# ...      ...   ...     ...    ...       ...        ...                   ...
# 27425  0.663  1.04   287.0  0.787  0.002690   402418.0                  1.05
# 27426  0.908  1.22   401.0  1.100  0.012700  1899893.0                  4.94
# 27427  0.893  1.11   366.0  1.000  0.002820   421866.0                  1.10
# 27428  0.351  1.02   207.0  0.565  0.001330   198965.0                  0.52
# 27429  0.588  1.04   268.0  0.733  0.010300  1540858.0                  4.01
#
#             n  condition_code
# 0      1.5700             7.0
# 1      0.6167             6.0
# 2      1.5380             0.0
# 3      0.2458             9.0
# 4      0.2879             7.0
# ...       ...             ...
# 27425  1.2520             6.0
# 27426  0.8979             7.0
# 27427  0.9841             0.0
# 27428  1.7430             7.0
# 27429  1.3450             6.0
#
# [27405 rows x 31 columns]

# %% [markdown]
# Sistemiamo ora i Dtype delle variabili

# %%
merged.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27405 entries, 0 to 27429
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   full_name               27405 non-null  object
#  1   close_approach_date     27405 non-null  object
#  2   distance_au             27405 non-null  float64
#  3   dist_km                 27405 non-null  float64
#  4   dist_lunar              27405 non-null  float64
#  5   distance_min_au         27405 non-null  float64
#  6   distance_max_au         27405 non-null  float64
#  7   velocity_km_s           27405 non-null  float64
#  8   v_rel_kmh               27405 non-null  float64
#  9   velocity_infinity_km_s  27405 non-null  float64
#  10  absolute_magnitude      27405 non-null  float64
#  11  is_future               27405 non-null  bool
#  12  spkid                   27405 non-null  float64
#  13  pha                     27405 non-null  object
#  14  diameter_km             27405 non-null  float64
#  15  diameter_m              27405 non-null  float64
#  16  diameter_is_estimated   27405 non-null  object
#  17  size_category           27405 non-null  object
#  18  class                   27405 non-null  object
#  19  e                       27405 non-null  float64
#  20  a                       27405 non-null  float64
#  21  i                       27405 non-null  float64
#  22  q                       27405 non-null  float64
#  23  ad                      27405 non-null  float64
#  24  per                     27405 non-null  float64
#  25  per_y                   27405 non-null  float64
#  26  moid_au                 27405 non-null  float64
#  27  moid_km                 27405 non-null  float64
#  28  moid_lunar_distances    27405 non-null  float64
#  29  n                       27405 non-null  float64
#  30  condition_code          27405 non-null  float64
# dtypes: bool(1), float64(24), object(6)
# memory usage: 15.1 MB

# %%
merged['close_approach_date'] = pd.to_datetime(merged['close_approach_date'])
merged['is_future'] = merged['is_future'].astype(bool)
merged["pha"] = merged["pha"].astype(bool)
merged["diameter_is_estimated"] = merged["diameter_is_estimated"].astype(bool)
size_order = [
    'Tiny (<25m) — Airburst/harmless',
    'Small (25-140m) — Local damage',
    'Medium (140m-1km) — Regional damage',
    'Large (>1 km) — City killer+'
]

merged['size_category'] = pd.Categorical(
    merged['size_category'], 
    categories=size_order, 
    ordered=True
)
merged['class'] = pd.Categorical(merged['class'])
merged['spkid'] = merged['spkid'].astype(np.int64)

# %%
assert (merged['e'].between(0, 1)).all(), "eccentricity out of range"
assert (merged['i'].between(0, 180)).all(), "inclination out of range"
assert (merged['moid_au'].dropna() >= 0).all(), "moid_au negative"
assert (merged['condition_code'].dropna().between(0, 9)).all(), "condition_code out of range"

# %%
mask = merged['distance_au'] > merged['distance_max_au']
print(merged[mask][['distance_min_au', 'distance_au', 'distance_max_au']])
print(f"Bad rows: {mask.sum()}")
# Out:
#        distance_min_au  distance_au  distance_max_au
# 2091          0.002572     0.002578         0.002577
# 4426          0.009662     0.009662         0.009662
# 6050          0.007376     0.007384         0.007376
# 7622          0.008570     0.008571         0.008570
# 8909          0.004472     0.004472         0.004472
# 12199         0.007497     0.007497         0.007497
# 13768         0.008756     0.008757         0.008756
# 19402         0.011193     0.011195         0.011193
# 20114         0.005540     0.005541         0.005540
# Bad rows: 9

# %% [markdown]
# Il valore nominale distance_au risulta più basso di distance_max_au per alcune istanze, questo probabilmente è dovuto ad errori da arrotondamenti, infatti l'errore è molto piccolo. Risolviamo portando distance_max_au al valore calcolato in distance_au dove questo è maggiore.

# %%
merged['distance_max_au'] = merged[['distance_au', 'distance_max_au']].max(axis=1)

# %%
merged.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27405 entries, 0 to 27429
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   full_name               27405 non-null  object
#  1   close_approach_date     27405 non-null  datetime64[ns]
#  2   distance_au             27405 non-null  float64
#  3   dist_km                 27405 non-null  float64
#  4   dist_lunar              27405 non-null  float64
#  5   distance_min_au         27405 non-null  float64
#  6   distance_max_au         27405 non-null  float64
#  7   velocity_km_s           27405 non-null  float64
#  8   v_rel_kmh               27405 non-null  float64
#  9   velocity_infinity_km_s  27405 non-null  float64
#  10  absolute_magnitude      27405 non-null  float64
#  11  is_future               27405 non-null  bool
#  12  spkid                   27405 non-null  int64
#  13  pha                     27405 non-null  bool
#  14  diameter_km             27405 non-null  float64
#  15  diameter_m              27405 non-null  float64
#  16  diameter_is_estimated   27405 non-null  bool
#  17  size_category           27405 non-null  category
#  18  class                   27405 non-null  category
#  19  e                       27405 non-null  float64
#  20  a                       27405 non-null  float64
#  21  i                       27405 non-null  float64
#  22  q                       27405 non-null  float64
#  23  ad                      27405 non-null  float64
#  24  per                     27405 non-null  float64
#  25  per_y                   27405 non-null  float64
#  26  moid_au                 27405 non-null  float64
#  27  moid_km                 27405 non-null  float64
#  28  moid_lunar_distances    27405 non-null  float64
#  29  n                       27405 non-null  float64
#  30  condition_code          27405 non-null  float64
# dtypes: bool(3), category(2), datetime64[ns](1), float64(23), int64(1), object(1)
# memory usage: 7.1 MB
